# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
 
html = urlopen("https://finance.sina.com.cn/stock/")
bsObj = BeautifulSoup(html)

for link in bsObj.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# http://www.sina.com.cn/
# https://finance.sina.com.cn/zt_d/315_2020/
# https://finance.sina.com.cn/edu/2020-03-13/doc-iimxyqwa0005852.shtml?daxuesource=pcfs
# https://finance.sina.com.cn/edu/2020-03-13/doc-iimxxstf8486051.shtml?daxuesource=pcfs
# http://finance.sina.com.cn/video/?from=g1
# javascript:;
# javascript:;
# http://www.sina.com.cn/
# http://finance.sina.com.cn/stock/
# https://finance.sina.com.cn/mobile/comfinanceweb.shtml?source=gupiao07
# http://finance.sina.com.cn/dav/
# http://tzxy.sina.com.cn
# javascript:
# javascript:
# http://i3.sinaimg.cn/dy/home/desktop/finance_stock.exe
# http://finance.sina.com.cn/
# http://www.sina.com.cn/
# http://news.sina.com.cn/guide/
# http://finance.sina.com.cn/
# http://finance.sina.com.cn/stock/
# http://finance.sina.com.cn/stock/newstock/
# http://finance.sina.com.cn/stock/quanshang/
# http://finance.sina.com.cn/fund/
# http://finance.sina.com.cn/stock/hkstock/
# http://finance.sina.com.cn/stock/usstock/
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import random
import datetime

random.seed(datetime.datetime.now())
def getLinks(articalUrl):
    html = urlopen("http://finance.sina.com.cn/stock/hkstock/index.shtml"+articalUrl)
    bsObj = BeautifulSoup(html)
    return bsObj.find('idv',{"id":"bodyContent"}).findAll("a")

links = getLinks("股票")
wihle len(links) > 0:
    newArtical = links[random.randint(0,len(links)-1)].atrrs["href"]
    print(newArtical)
    links = getLinks(newArtical)
